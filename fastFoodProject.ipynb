# %% [markdown]
# <a href="https://colab.research.google.com/github/emailsri23/DS_Project_Repository/blob/master/fastFoodProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df1.loc[df1.websites.isnull(), 'websites'] = df1.loc[df1.websites.isnull(),'name'].map((df1.loc[df1.websites.notnull()]).set_index('name','websites'))
df1 = df_restaurants[['name' ,'websites']]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/FastFoodRestaurants.csv')
df1['province'].value_counts().size
# Out:
# 52

# %%
#df1.loc[df1.websites.isnull(), 'websites'] = df1.loc[df1.websites.isnull(),'name'].map((df1.loc[df1.websites.notnull()]).set_index('name','websites'))
#df1.loc[df1.websites.isnull(), 'websites']
#df2= df1.websites.interpolate()
#df1.loc[df1.websites.isnull(), 'websites'].interpolate()
df1.loc[df1.websites.isnull(), 'websites']
# Out:
# 37      NaN
# 137     NaN
# 262     NaN
# 292     NaN
# 303     NaN
#        ...
# 9959    NaN
# 9961    NaN
# 9976    NaN
# 9978    NaN
# 9981    NaN
# Name: websites, Length: 465, dtype: object

# %%
df1.loc[df1.address.isnull(), 'address']
# Out:
# Series([], Name: address, dtype: object)

# %%
df1.loc[df1.city.isnull(), 'city']
# Out:
# Series([], Name: city, dtype: object)

# %%
df1.loc[df1.country.isnull(), 'country']
# Out:
# Series([], Name: country, dtype: object)

# %%
df1.dtypes
#df1.loc[df1.keys.isnull(), 'keys']
# Out:
# address        object
# city           object
# country        object
# keys           object
# latitude      float64
# longitude     float64
# name           object
# postalCode     object
# province       object
# websites       object
# dtype: object

# %%
#DataFrame.interpolate(self, method='pad', axis='websites', limit=None, inplace=False, limit_direction='forward', limit_area='inside', downcast=None, **kwargs)
df1['name'].value_counts().size
# Out:
# 548

# %%
#inp = pd.read_csv('filename.csv') # read input. Add read_csv arguments as needed
#columns = pd.DataFrame({'column_names': inp.columns, 'datatypes': inp.dtypes})
#columns.to_csv(inp+'columns_list.csv', encoding='utf-8') # encoding is optional

df3 = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/FastFoodRestaurants.csv')
df4 = pd.DataFrame({'shopName': df3.name, 'websites': df3.websites})
df4
# Out:
#                          shopName                                           websites
# 0                      McDonald's  http://mcdonalds.com,http://www.mcdonalds.com/...
# 1                         Wendy's                              http://www.wendys.com
# 2                Frisch's Big Boy  http://www.frischs.com,https://www.frischs.com...
# 3                      McDonald's  http://mcdonalds.com,http://www.mcdonalds.com/...
# 4                 OMG! Rotisserie  http://www.omgrotisserie.com,http://omgrotisse...
# ...                           ...                                                ...
# 9995                      Wendy's            http://www.wendys.com,http://wendys.com
# 9996  Lee's Oriental Martial Arts                           http://www.mcdonalds.com
# 9997                    Five Guys                                http://fiveguys.com
# 9998                El Pollo Loco  http://www.elpolloloco.com,http://elpolloloco.com
# ...

# %%
#for row in df1.rows:
   #print row['c1'], row['c2']
for row in df1.rows:
  if(df1.websites).isnull: 
    for row in df5.rows: 
      if(df1.name.equals(df5.ShopName): 
        df1.websites.replace(to_replace=r'^*.$', value=df5.websites, regex=True))
df1
# Out:
#   File "<ipython-input-26-e4257c86e593>", line 4
#     if(df1.name.equals(df5.ShopName):
#                                     ^
# SyntaxError: invalid syntax

# %%
for row in df1.websites:  
  if(df1.websites).isnull: print("This is fine")
# Out:
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# This is fine
# ...

# %%
#for row in df1.websites:  
#  if(df1.websites).isnull: "This is fine"
for row in df5.shopName: 
  if(df1.name.equals(df5.shopName)): 
    df1.websites.replace(to_replace='NaN', value=df5.websites, regex=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-d8917994ea14> in <module>()
#       1 for row in df5.shopName:
#       2   if(df1.name.equals(df5.shopName)):
# ----> 3     df1.websites.replace(to_replace='NaN', value=df5.websites, regex=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4365             limit=limit,
#    4366             regex=regex,
# -> 4367             method=method,
#    4368         )
#    4369
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6770                                 filter=[k],
#    6771                                 inplace=inplace,
# -> 6772                                 regex=regex,
#    6773                             )
#    6774
#
# ...

# %%
df10 = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/FastFoodRestaurants.csv')
df11 = pd.DataFrame({'shopName': df10.name, 'websites': df10.websites})
#df11
for row in df10.websites: 
  if(df10.websites).isnull: 
    for row in df11.shopName: 
      if(df11.shopName.equals(df10.name)): 
        df10.websites.replace(to_replace='NaN', value=df11.websites)
        df10.loc[df10.websites.isnull(), 'websites']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-36875c6f965d> in <module>()
#       6     for row in df11.shopName:
#       7       if(df11.shopName.equals(df10.name)):
# ----> 8         df10.websites.replace(to_replace='NaN', value=df11.websites)
#       9         df10.loc[df10.websites.isnull(), 'websites']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4365             limit=limit,
#    4366             regex=regex,
# -> 4367             method=method,
#    4368         )
#    4369
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6770                                 filter=[k],
#    6771                                 inplace=inplace,
# ...

# %%
df10 = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/FastFoodRestaurants.csv')
df11 = pd.DataFrame({'shopName': df10.name, 'websites': df10.websites})
i = 0
j=0
for row in df10.websites: 
  if(df10.websites).isnull:
    i=i+1
    print("i is - ",i)
    for row in df11.shopName: 
      if(df11.websites.notnull):
        df10.websites.replace(to_replace='NaN', value=df11.websites)
        J=j+1
        print("j is - ",j)

df10.loc[df10.websites.isnull(), 'websites']
# Out:
#   File "<ipython-input-57-8326da322c5b>", line 6
#     for row=df11.shopName.equals(df10.name) in df11.shopName:
#            ^
# SyntaxError: invalid syntax

# %%
df10 = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/FastFoodRestaurants.csv')
df11 = pd.DataFrame({'shopName': df10.name, 'websites': df10.websites})
if(df11.shopName.equals(df10.name)): 
  print(df11.websites)
# Out:
# 0       http://mcdonalds.com,http://www.mcdonalds.com/...
# 1                                   http://www.wendys.com
# 2       http://www.frischs.com,https://www.frischs.com...
# 3       http://mcdonalds.com,http://www.mcdonalds.com/...
# 4       http://www.omgrotisserie.com,http://omgrotisse...
#                               ...
# 9995              http://www.wendys.com,http://wendys.com
# 9996                             http://www.mcdonalds.com
# 9997                                  http://fiveguys.com
# 9998    http://www.elpolloloco.com,http://elpolloloco.com
# 9999                               http://www.carlsjr.com
# Name: websites, Length: 10000, dtype: object

# %%
for name, values in df1.iteritems():
    print('{name}: {value}'.format(name=name, value=values[0]))
# Out:
# address: 324 Main St
# city: Massena
# country: US
# keys: us/ny/massena/324mainst/-1161002137
# latitude: 44.9213
# longitude: -74.89021
# name: McDonald's
# postalCode: 13662
# province: NY
# websites: http://mcdonalds.com,http://www.mcdonalds.com/?cid=RF:YXT_FM:TP::Yext:Referral

# %%
#sample code @ https://stackoverflow.com/questions/28218698/how-to-iterate-over-columns-of-pandas-dataframe-to-run-regression


import pandas as pd
# setting options to print without truncating output
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

import statsmodels.formula.api as smf
import itertools

# This section gets the column names of the DF and removes some columns which I don't want to use as predictors.
itercols = aft_tmt.columns.tolist()
itercols.remove("sc97")
itercols.remove("sc")
itercols.remove("grc")
itercols.remove("grc97")
print itercols
len(itercols)

# results DF
regression_res = pd.DataFrame(columns = ["Rsq", "predictors", "excluded"])

# excluded cols
exc = []

# change 9 to the number of columns you want to combine from N columns.
#Possibly run an outer loop from 0 to N/2?
for x in itertools.combinations(itercols, 9):
    lmstr = "+".join(x)
    m = smf.ols(formula = "sc ~ " + lmstr, data = aft_tmt)
    f = m.fit()
    exc = [item for item in x if item not in itercols]
    regression_res = regression_res.append(pd.DataFrame([[f.rsquared, lmstr, "+".join([y for y in itercols if y not in list(x)])]], columns = ["Rsq", "predictors", "excluded"]))

regression_res.sort_values(by="Rsq", ascending = False)
# Out:
#   File "<ipython-input-21-58270f3d0dc6>", line 1
#     for i in len(df1): if i + 1 != len(df1): # sm.OLS(returns[returns.coloumns[i]], returns[returns.columns[ i+1]]), fit()
#                         ^
# SyntaxError: invalid syntax
